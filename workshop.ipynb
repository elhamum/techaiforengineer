# %%
# Use GitHub Copilot to:
# - import pandas
# - import matplotlib.pyplot
# - import the required modules from scikit-learn for:
#   - train_test_split
#   - LinearRegression
#   - model evaluation (R2 and MSE)

# %% [markdown]
# # Use Copilot to:
# # - load 'house_consumption.csv' into a DataFrame called df
# # - display the first 5 rows
# # - show dataset information (columns, data types, missing values)
# # - show a statistical summary of the data

# %% [markdown]
# # Use Copilot to:
# # - print the number of missing values in each column
# # - remove duplicate rows if they exist
# # - fill missing numeric values using a reasonable method
# # - print a short summary of what changed after cleaning

# %% [markdown]
# # Use Copilot to:
# # - compute the correlation matrix for numeric columns
# # - create a heatmap using matplotlib (do NOT use seaborn)
# # - add a title and readable axis labels

# %% [markdown]
# # Use Copilot to:
# # - create a scatter plot showing the relationship between
# #   one input feature and energy consumption
# # - label axes and add a title

# %% [markdown]
# # Use Copilot to:
# # - define X (input features)
# # - define y as the target variable 'Consumption'
# # - split the data into training and testing sets (80/20)
# # - set random_state=42

# %% [markdown]
# # Use Copilot to:
# # - create a Linear Regression model
# # - train (fit) the model using the training data

# %% [markdown]
# # Use Copilot to:
# # - predict energy consumption for the test set
# # - calculate R2 score
# # - calculate Mean Squared Error (MSE)
# # - print both metrics clearly
